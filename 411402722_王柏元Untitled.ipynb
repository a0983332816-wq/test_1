# %% [markdown]
# <a href="https://colab.research.google.com/github/a0983332816-wq/test_1/blob/main/411402722_%E7%8E%8B%E6%9F%8F%E5%85%83Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =========================
# 1.解壓縮face_data.zip
# =========================
import zipfile
import os

zip_path = "/content/Dataset.zip" #查看zip檔名是否正確
extract_path = "/content/Dataset" #查看資料夾路徑是否正確

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("解壓完成")

# =========================
# 2.安裝套件
# =========================
# !pip install ultralytics

# =========================
# 3.切分資料（train/val/test = 8:1:1）
# =========================
import shutil
import random

# 解壓後
base_dir = "/content/Dataset/Dataset"
output_dir = "/content/dataset"

classes = ["Bus", "Car", "motorcycle", "Truck"

]

for cls in classes:
    img_dir = os.path.join(base_dir, cls)

    images = os.listdir(img_dir)
    random.shuffle(images)

    total = len(images)

    train_split = int(total * 0.8)
    val_split = int(total * 0.9)

    train_imgs = images[:train_split]
    val_imgs = images[train_split:val_split]
    test_imgs = images[val_split:]

    for split_name, split_data in [
        ("train", train_imgs),
        ("val", val_imgs),
        ("test", test_imgs)
    ]:
        save_dir = os.path.join(output_dir, split_name, cls)
        os.makedirs(save_dir, exist_ok=True)

        for img in split_data:
            shutil.copy(
                os.path.join(img_dir, img),
                os.path.join(save_dir, img)
            )

print("資料切分完成")

# =========================
#  4.訓練 YOLO 情緒分類模型
# =========================
from ultralytics import YOLO

model = YOLO("yolov8n-cls.pt")

model.train(
    data="/content/dataset",
    epochs=10,
    imgsz=224
)

# =========================
#  5.驗證模型（val）
# =========================
metrics = model.val()
print(metrics)

# =========================
# 6.test 前5張預測 + 顯示結果
# =========================
import cv2
import random
from google.colab.patches import cv2_imshow

# 載入最佳模型
model = YOLO("runs/classify/train/weights/best.pt")

test_dir = "/content/dataset/test"

names = ["Bus", "Car", "motorcycle", "Truck"

]

# 收集所有圖片
all_images = []

for cls in os.listdir(test_dir):
    cls_path = os.path.join(test_dir, cls)

    for img_name in os.listdir(cls_path):
        all_images.append(os.path.join(cls_path, img_name))

# 圖片隨機打亂（更公平）
random.shuffle(all_images)

# =========================
# 7.顯示前5張結果
# =========================
for i, img_path in enumerate(all_images[:5]):

    results = model(img_path)
    img = cv2.imread(img_path)

    for r in results:
        top1 = r.probs.top1
        conf = r.probs.top1conf
        label = names[top1]

        print(f"[{i+1}] {os.path.basename(img_path)} → {label} ({conf:.2f})")

        cv2.putText(img,
                    f"{label} {conf:.2f}",
                    (30, 50),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    1,
                    (0, 255, 0),
                    2)
    cv2_imshow(img)



#程式結束
# Out:
# 解壓完成
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.12/dist-packages (8.4.51)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.10.0+cpu)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.25.0+cpu)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.35.2)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.19)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (26.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.20.0->ultralytics) (1.35.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2026.4.22)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# 資料切分完成
# Ultralytics 8.4.51 🚀 Python-3.12.13 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/dataset, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=10, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train-2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/classify/train-2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: /content/dataset/train... found 531 images in 7 classes ✅
# val: /content/dataset/val... found 67 images in 7 classes ✅
# test: /content/dataset/test... found 66 images in 7 classes ✅
# Overriding model.yaml nc=1000 with nc=7
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    339207  ultralytics.nn.modules.head.Classify         [256, 7]
# YOLOv8n-cls summary: 56 layers, 1,447,255 parameters, 1,447,255 gradients, 3.4 GFLOPs
# Transferred 156/158 items from pretrained weights
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 401.7±106.5 MB/s, size: 82.5 KB)
# train: Scanning /content/dataset/train... 531 images, 0 corrupt: 100% ━━━━━━━━━━━━ 531/531 1.2Kit/s 0.4s
# train: /content/dataset/train/Bus/Image_11.jpg: corrupt JPEG restored and saved
# train: /content/dataset/train/Truck/Image_8.JPG: corrupt JPEG restored and saved
# train: New cache created: /content/dataset/train.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1430.8±580.9 MB/s, size: 213.5 KB)
# val: Scanning /content/dataset/val... 67 images, 0 corrupt: 100% ━━━━━━━━━━━━ 67/67 2.4Kit/s 0.0s
# val: New cache created: /content/dataset/val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000909, momentum=0.9) with parameter groups 26 weight(decay=0.0), 27 weight(decay=0.0005), 27 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 0 dataloader workers
# Logging results to /content/runs/classify/train-2
# Starting training for 10 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/10         0G      1.793          3        224: 100% ━━━━━━━━━━━━ 34/34 1.3s/it 45.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.3s/it 3.8s
#                    all      0.627       0.97
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/10         0G      1.052          3        224: 100% ━━━━━━━━━━━━ 34/34 1.5s/it 51.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.3s/it 3.9s
#                    all      0.731          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/10         0G     0.6355          3        224: 100% ━━━━━━━━━━━━ 34/34 1.3s/it 45.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.3s/it 3.8s
#                    all      0.746          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/10         0G     0.4967          3        224: 100% ━━━━━━━━━━━━ 34/34 1.3s/it 43.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.6s/it 4.8s
#                    all      0.836          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/10         0G     0.3548          3        224: 100% ━━━━━━━━━━━━ 34/34 1.3s/it 44.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.3s/it 4.0s
#                    all      0.776          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/10         0G     0.3481          3        224: 100% ━━━━━━━━━━━━ 34/34 1.3s/it 43.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.2s/it 3.7s
#                    all      0.896          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/10         0G     0.2663          3        224: 100% ━━━━━━━━━━━━ 34/34 1.3s/it 43.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.3s/it 3.9s
#                    all      0.851          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/10         0G     0.2216          3        224: 100% ━━━━━━━━━━━━ 34/34 1.3s/it 44.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.6s/it 4.7s
#                    all      0.836          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/10         0G     0.2367          3        224: 100% ━━━━━━━━━━━━ 34/34 1.3s/it 43.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.6s/it 4.8s
#                    all      0.836          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/10         0G     0.2179          3        224: 100% ━━━━━━━━━━━━ 34/34 1.3s/it 44.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.3s/it 4.0s
#                    all      0.866          1
#
# 10 epochs completed in 0.137 hours.
# Optimizer stripped from /content/runs/classify/train-2/weights/last.pt, 3.0MB
# Optimizer stripped from /content/runs/classify/train-2/weights/best.pt, 3.0MB
#
# Validating /content/runs/classify/train-2/weights/best.pt...
# Ultralytics 8.4.51 🚀 Python-3.12.13 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# YOLOv8n-cls summary (fused): 30 layers, 1,443,847 parameters, 0 gradients, 3.3 GFLOPs
# train: /content/dataset/train... found 531 images in 7 classes ✅
# val: /content/dataset/val... found 67 images in 7 classes ✅
# test: /content/dataset/test... found 66 images in 7 classes ✅
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 3/3 1.5s/it 4.5s
#                    all      0.896          1
# Speed: 0.0ms preprocess, 11.4ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /content/runs/classify/train-2
# Ultralytics 8.4.51 🚀 Python-3.12.13 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# YOLOv8n-cls summary (fused): 30 layers, 1,443,847 parameters, 0 gradients, 3.3 GFLOPs
# train: /content/dataset/train... found 531 images in 7 classes ✅
# val: /content/dataset/val... found 67 images in 7 classes ✅
# test: /content/dataset/test... found 66 images in 7 classes ✅
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1935.4±616.9 MB/s, size: 213.5 KB)
# val: Scanning /content/dataset/val... 67 images, 0 corrupt: 100% ━━━━━━━━━━━━ 67/67 14.1Mit/s 0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 5/5 1.3it/s 3.8s
#                    all      0.896          1
# Speed: 0.0ms preprocess, 11.3ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /content/runs/classify/val-2
# ultralytics.utils.metrics.ClassifyMetrics object with attributes:
#
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7c28ac446cf0>
# curves: []
# curves_results: []
# fitness: 0.947761207818985
# keys: ['metrics/accuracy_top1', 'metrics/accuracy_top5']
# results_dict: {'metrics/accuracy_top1': 0.89552241563797, 'metrics/accuracy_top5': 1.0, 'fitness': 0.947761207818985}
# save_dir: PosixPath('/content/runs/classify/val-2')
# speed: {'preprocess': 0.002309358227540176, 'inference': 11.254855820893614, 'loss': 0.0001295820766245015, 'postprocess': 0.0002699104440051006}
# top1: 0.89552241563797
# top5: 1.0
#
# image 1/1 /content/dataset/test/Car/Image_67.jpg: 224x224 Sad 0.53, Angry 0.31, Happy 0.16, 20.7ms
# Speed: 5.2ms preprocess, 20.7ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# [1] Image_67.jpg → motorcycle (0.53)
# <PIL.Image.Image image mode=RGB size=600x400>
# image 1/1 /content/dataset/test/motorcycle/Image_65.jpg: 224x224 Happy 0.71, Sad 0.17, Angry 0.11, 34.7ms
# Speed: 9.6ms preprocess, 34.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# [2] Image_65.jpg → Car (0.71)
# <PIL.Image.Image image mode=RGB size=600x400>
# image 1/1 /content/dataset/test/Car/Image_59.jpg: 224x224 Sad 0.75, Angry 0.18, Happy 0.07, 52.7ms
# Speed: 11.2ms preprocess, 52.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# [3] Image_59.jpg → motorcycle (0.75)
# <PIL.Image.Image image mode=RGB size=458x305>
# image 1/1 /content/dataset/test/Angry/crying-when-angry-1296x728-header.jpg: 224x224 Angry 0.53, Happy 0.26, Sad 0.22, 36.5ms
# Speed: 20.4ms preprocess, 36.5ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# [4] crying-when-angry-1296x728-header.jpg → Bus (0.53)
# <PIL.Image.Image image mode=RGB size=1296x728>
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.55, Sad 0.39, Happy 0.06, 48.5ms
# video 1/1 (frame 2/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.55, Sad 0.39, Happy 0.06, 36.0ms
# video 1/1 (frame 3/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.51, Sad 0.45, Happy 0.04, 29.7ms
# video 1/1 (frame 4/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Sad 0.49, Angry 0.47, Happy 0.05, 27.8ms
# video 1/1 (frame 5/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.57, Sad 0.38, Happy 0.05, 33.7ms
# video 1/1 (frame 6/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.49, Sad 0.45, Happy 0.06, 33.1ms
# video 1/1 (frame 7/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.50, Sad 0.43, Happy 0.07, 28.3ms
# video 1/1 (frame 8/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.50, Sad 0.45, Happy 0.06, 27.3ms
# video 1/1 (frame 9/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Sad 0.47, Angry 0.47, Happy 0.05, 22.9ms
# video 1/1 (frame 10/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Sad 0.50, Angry 0.44, Happy 0.06, 24.3ms
# video 1/1 (frame 11/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.50, Sad 0.44, Happy 0.06, 22.8ms
# video 1/1 (frame 12/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.53, Sad 0.42, Happy 0.05, 24.5ms
# video 1/1 (frame 13/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.62, Sad 0.32, Happy 0.06, 26.0ms
# video 1/1 (frame 14/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.51, Sad 0.43, Happy 0.06, 28.9ms
# video 1/1 (frame 15/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.50, Sad 0.43, Happy 0.06, 43.3ms
# video 1/1 (frame 16/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.50, Sad 0.43, Happy 0.06, 39.6ms
# video 1/1 (frame 17/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.51, Sad 0.42, Happy 0.07, 47.1ms
# video 1/1 (frame 18/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Sad 0.53, Angry 0.41, Happy 0.06, 27.6ms
# video 1/1 (frame 19/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.54, Sad 0.40, Happy 0.06, 23.1ms
# video 1/1 (frame 20/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Sad 0.46, Angry 0.46, Happy 0.07, 24.6ms
# video 1/1 (frame 21/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.53, Sad 0.41, Happy 0.06, 24.4ms
# video 1/1 (frame 22/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.48, Sad 0.46, Happy 0.06, 22.9ms
# video 1/1 (frame 23/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Sad 0.48, Angry 0.45, Happy 0.07, 23.3ms
# video 1/1 (frame 24/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.57, Sad 0.37, Happy 0.07, 23.0ms
# video 1/1 (frame 25/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.62, Sad 0.32, Happy 0.05, 22.9ms
# video 1/1 (frame 26/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.60, Sad 0.35, Happy 0.05, 23.7ms
# video 1/1 (frame 27/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.55, Sad 0.39, Happy 0.06, 28.1ms
# video 1/1 (frame 28/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.56, Sad 0.38, Happy 0.07, 33.7ms
# video 1/1 (frame 29/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.57, Sad 0.36, Happy 0.07, 31.5ms
# video 1/1 (frame 30/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.49, Sad 0.44, Happy 0.07, 31.3ms
# video 1/1 (frame 31/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.50, Sad 0.42, Happy 0.08, 35.0ms
# video 1/1 (frame 32/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.52, Sad 0.41, Happy 0.07, 25.9ms
# video 1/1 (frame 33/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.55, Sad 0.39, Happy 0.07, 24.0ms
# video 1/1 (frame 34/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.55, Sad 0.39, Happy 0.06, 24.2ms
# video 1/1 (frame 35/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.52, Sad 0.40, Happy 0.08, 25.0ms
# video 1/1 (frame 36/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.52, Sad 0.40, Happy 0.07, 21.7ms
# video 1/1 (frame 37/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.52, Sad 0.41, Happy 0.07, 23.2ms
# video 1/1 (frame 38/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.59, Sad 0.34, Happy 0.07, 22.3ms
# video 1/1 (frame 39/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.56, Sad 0.37, Happy 0.07, 23.6ms
# video 1/1 (frame 40/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.55, Sad 0.37, Happy 0.07, 24.7ms
# video 1/1 (frame 41/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.53, Sad 0.39, Happy 0.08, 24.9ms
# video 1/1 (frame 42/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.54, Sad 0.39, Happy 0.08, 22.6ms
# video 1/1 (frame 43/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.50, Sad 0.42, Happy 0.07, 24.1ms
# video 1/1 (frame 44/44) /content/dataset/test/Sad/crying-sad.gif: 224x224 Angry 0.51, Sad 0.42, Happy 0.07, 43.4ms
# Speed: 4.4ms preprocess, 28.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# [5] crying-sad.gif → Bus (0.55)
# [5] crying-sad.gif → Bus (0.55)
# [5] crying-sad.gif → Bus (0.51)
# [5] crying-sad.gif → motorcycle (0.49)
# [5] crying-sad.gif → Bus (0.57)
# [5] crying-sad.gif → Bus (0.49)
# [5] crying-sad.gif → Bus (0.50)
# [5] crying-sad.gif → Bus (0.50)
# [5] crying-sad.gif → motorcycle (0.47)
# [5] crying-sad.gif → motorcycle (0.50)
# [5] crying-sad.gif → Bus (0.50)
# [5] crying-sad.gif → Bus (0.53)
# [5] crying-sad.gif → Bus (0.62)
# [5] crying-sad.gif → Bus (0.51)
# [5] crying-sad.gif → Bus (0.50)
# [5] crying-sad.gif → Bus (0.50)
# [5] crying-sad.gif → Bus (0.51)
# [5] crying-sad.gif → motorcycle (0.53)
# [5] crying-sad.gif → Bus (0.54)
# [5] crying-sad.gif → motorcycle (0.46)
# [5] crying-sad.gif → Bus (0.53)
# [5] crying-sad.gif → Bus (0.48)
# [5] crying-sad.gif → motorcycle (0.48)
# [5] crying-sad.gif → Bus (0.57)
# [5] crying-sad.gif → Bus (0.62)
# [5] crying-sad.gif → Bus (0.60)
# [5] crying-sad.gif → Bus (0.55)
# [5] crying-sad.gif → Bus (0.56)
# [5] crying-sad.gif → Bus (0.57)
# [5] crying-sad.gif → Bus (0.49)
# [5] crying-sad.gif → Bus (0.50)
# [5] crying-sad.gif → Bus (0.52)
# [5] crying-sad.gif → Bus (0.55)
# [5] crying-sad.gif → Bus (0.55)
# [5] crying-sad.gif → Bus (0.52)
# [5] crying-sad.gif → Bus (0.52)
# [5] crying-sad.gif → Bus (0.52)
# [5] crying-sad.gif → Bus (0.59)
# [5] crying-sad.gif → Bus (0.56)
# [5] crying-sad.gif → Bus (0.55)
# [5] crying-sad.gif → Bus (0.53)
# [5] crying-sad.gif → Bus (0.54)
# [5] crying-sad.gif → Bus (0.50)
# [5] crying-sad.gif → Bus (0.51)
# <PIL.Image.Image image mode=RGB size=220x268>
