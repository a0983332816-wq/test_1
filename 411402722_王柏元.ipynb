# %% [markdown]
# <a href="https://colab.research.google.com/github/a0983332816-wq/test_1/blob/main/411402722_%E7%8E%8B%E6%9F%8F%E5%85%83.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 多張車輛辨識車牌號碼程式
# 安裝套件
# !pip install ultralytics easyocr -q
import zipfile
import os
import cv2
import random
import matplotlib.pyplot as plt
from ultralytics import YOLO
import easyocr
# 解壓 ZIP
zip_path = "/content/car_images.zip"
extract_path = "/content/images/images/images/images"
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)
print("解壓完成")

# 載入模型
model = YOLO("yolov8n.pt")
reader = easyocr.Reader(['en'])
# 輸出檔案
output_file = "car_OK.txt"
# 用來存「顯示用結果」
results_list = []
# 批次辨識
with open(output_file, "w", encoding="utf-8") as f:
    for img_name in os.listdir(extract_path):
        if not img_name.lower().endswith(('.jpg', '.png', '.jpeg')):
            continue
        img_path = os.path.join(extract_path, img_name)
        img = cv2.imread(img_path)
        if img is None:
            continue
        # YOLO 偵測
        results = model(img_path)
        plate_text = "NOT_FOUND"
        for r in results:
            for box in r.boxes:
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                x1, y1 = max(0, x1), max(0, y1)
                x2, y2 = min(img.shape[1], x2), min(img.shape[0], y2)
                crop = img[y1:y2, x1:x2]
                ocr_result = reader.readtext(crop)
                text = "".join([t[1] for t in ocr_result]).strip()
                if text != "":
                    plate_text = text
                    cv2.rectangle(img, (x1, y1), (x2, y2), (0,255,0), 2)
                    cv2.putText(img, text, (x1, y1-10),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.8,
                                (0,255,0), 2)
                    break
        # 寫入 txt
        f.write(f"{img_name}\t{plate_text}\n")
        # 存起來給「隨機顯示用」
        results_list.append((img_name, img, plate_text))
        print(f"{img_name} → {plate_text}")

# 隨機顯示 5 張結果
sample_results = random.sample(results_list, min(5, len(results_list)))
for img_name, img, text in sample_results:
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(8,5))
    plt.imshow(img_rgb)
    plt.title(f"{img_name} - {text}")
    plt.axis("off")
    plt.show()
# Out:
# 解壓完成
#
# image 1/1 /content/images/images/images/images/816223.jpg: 448x640 7 cars, 101.6ms
# Speed: 12.7ms preprocess, 101.6ms inference, 52.5ms postprocess per image at shape (1, 3, 448, 640)
# 816223.jpg → KH 68012
#
# image 1/1 /content/images/images/images/images/972655.jpg: 448x640 2 persons, 1 car, 1 truck, 11.3ms
# Speed: 3.7ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 972655.jpg → JV30814
#
# image 1/1 /content/images/images/images/images/1030412.jpg: 448x640 5 cars, 12.6ms
# Speed: 3.4ms preprocess, 12.6ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
# 1030412.jpg → EE 82996
#
# image 1/1 /content/images/images/images/images/1007391.jpg: 448x640 2 cars, 1 bus, 6.7ms
# Speed: 2.2ms preprocess, 6.7ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 1007391.jpg → EF"AHIRANS AS2Juw10279Essstics
#
# image 1/1 /content/images/images/images/images/972404.jpg: 448x640 2 persons, 1 car, 7.1ms
# Speed: 2.2ms preprocess, 7.1ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 972404.jpg → CH19859
#
# image 1/1 /content/images/images/images/images/972486.jpg: 448x640 2 persons, 1 car, 6.6ms
# Speed: 2.1ms preprocess, 6.6ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
# 972486.jpg → 3oBXK30060Irtteio SE
#
# image 1/1 /content/images/images/images/images/1342295.jpg: 352x640 5 cars, 46.0ms
# Speed: 1.8ms preprocess, 46.0ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# 1342295.jpg → 2E61026
#
# image 1/1 /content/images/images/images/images/972408.jpg: 384x640 1 car, 1 truck, 46.3ms
# Speed: 2.1ms preprocess, 46.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 972408.jpg → 7ZhMbaudsreder~(romso421710|
#
# image 1/1 /content/images/images/images/images/1007351.jpg: 448x640 2 cars, 1 truck, 1 surfboard, 7.3ms
# Speed: 2.5ms preprocess, 7.3ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# 1007351.jpg → VOLOBR428529XC70EROSS COUNTRY
#
# image 1/1 /content/images/images/images/images/972456.jpg: 448x640 1 car, 6.5ms
# Speed: 2.4ms preprocess, 6.5ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
# 972456.jpg → DR49108
#
# image 1/1 /content/images/images/images/images/1007317.jpg: 448x640 1 car, 1 truck, 11.6ms
# Speed: 3.4ms preprocess, 11.6ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
# 1007317.jpg → KH90283
#
# image 1/1 /content/images/images/images/images/1007331.jpg: 448x640 1 car, 6.4ms
# Speed: 2.1ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 1007331.jpg → S10605WoouCapi€XLI
#
# image 1/1 /content/images/images/images/images/973344.jpg: 448x640 7 cars, 6.3ms
# Speed: 2.2ms preprocess, 6.3ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
# 973344.jpg → LY88480
#
# image 1/1 /content/images/images/images/images/1007341.jpg: 448x640 3 cars, 1 truck, 6.5ms
# Speed: 2.4ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
# 1007341.jpg → fe&XV 66492Jtoyotatwwwnordvikno
#
# image 1/1 /content/images/images/images/images/1007353.jpg: 416x640 2 cars, 57.9ms
# Speed: 2.9ms preprocess, 57.9ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 640)
# 1007353.jpg → AS 32347
#
# image 1/1 /content/images/images/images/images/1007306.jpg: 448x640 1 person, 1 truck, 8.1ms
# Speed: 3.2ms preprocess, 8.1ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
# 1007306.jpg → F6AA50689
#
# image 1/1 /content/images/images/images/images/972509.jpg: 448x640 1 person, 1 car, 1 truck, 6.1ms
# Speed: 2.2ms preprocess, 6.1ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 972509.jpg → "IAHK18110
#
# image 1/1 /content/images/images/images/images/972429.jpg: 448x640 1 person, 2 cars, 6.2ms
# Speed: 2.0ms preprocess, 6.2ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 972429.jpg → BT92118
#
# image 1/1 /content/images/images/images/images/1007405.jpg: 448x640 1 car, 1 bus, 6.8ms
# Speed: 2.4ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
# 1007405.jpg → AA59357
#
# image 1/1 /content/images/images/images/images/1007346.jpg: 448x640 2 cars, 6.9ms
# Speed: 2.5ms preprocess, 6.9ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# 1007346.jpg → EE 19882
#
# image 1/1 /content/images/images/images/images/1007416.jpg: 448x640 2 persons, 2 cars, 1 truck, 6.5ms
# Speed: 2.2ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 1007416.jpg → BT43288
#
# image 1/1 /content/images/images/images/images/1161297.jpg: 448x640 2 cars, 6.5ms
# Speed: 2.1ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
# 1161297.jpg → DL 86430Taroruadalen-Blicenterno 0222500 50
#
# image 1/1 /content/images/images/images/images/996307.jpg: 448x640 1 truck, 9.6ms
# Speed: 2.5ms preprocess, 9.6ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 640)
# 996307.jpg → LH 48940March024
#
# image 1/1 /content/images/images/images/images/1007335.jpg: 448x640 2 persons, 1 car, 6.4ms
# Speed: 2.3ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 1007335.jpg → CF 76904
#
# image 1/1 /content/images/images/images/images/1007354.jpg: 448x640 1 car, 1 truck, 6.1ms
# Speed: 2.2ms preprocess, 6.1ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
# 1007354.jpg → RLV-2169Fe tred52544
